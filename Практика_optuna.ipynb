# %% [markdown]
# <a href="https://colab.research.google.com/github/mssamoilenko/1Git-HUB-together/blob/master/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_optuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# У цьому конкурсі вам потрібно проаналізувати набір даних про клієнтів Google Merchandise Store (також відомого як GStore, де продаються товари від Google), щоб передбачити дохід на кожного клієнта.
#
# [посилання](https://www.kaggle.com/competitions/ga-customer-revenue-prediction/overview)
#
# Перейшовши за посиланням, натисність кнопку `Late Submission`

# %% [markdown]
# Для завантаження даних використайте наступний код, ваша цільова ознака це стовпчик `totals_transactionRevenue`

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("/content/data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 58 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Unnamed: 0                                         100000 non-null  int64
#  1   channelGrouping                                    100000 non-null  object
#  2   date                                               100000 non-null  int64
#  3   fullVisitorId                                      100000 non-null  uint64
#  4   socialEngagementType                               100000 non-null  object
#  5   visitId                                            100000 non-null  int64
#  6   visitNumber                                        100000 non-null  int64
#  7   visitStartTime                                     100000 non-null  int64
#  8   device_browser                                     100000 non-null  object
#  9   device_browserVersion                              100000 non-null  object
#  10  device_browserSize                                 100000 non-null  object
#  11  device_operatingSystem                             100000 non-null  object
#  12  device_operatingSystemVersion                      100000 non-null  object
#  13  device_isMobile                                    100000 non-null  int64
#  14  device_mobileDeviceBranding                        100000 non-null  object
#  15  device_mobileDeviceModel                           100000 non-null  object
#  16  device_mobileInputSelector                         100000 non-null  object
#  17  device_mobileDeviceInfo                            100000 non-null  object
#  18  device_mobileDeviceMarketingName                   100000 non-null  object
#  19  device_flashVersion                                100000 non-null  object
#  20  device_language                                    100000 non-null  object
#  21  device_screenColors                                100000 non-null  object
#  22  device_screenResolution                            100000 non-null  object
#  23  device_deviceCategory                              100000 non-null  object
#  24  geoNetwork_continent                               100000 non-null  object
#  25  geoNetwork_subContinent                            100000 non-null  object
#  26  geoNetwork_country                                 100000 non-null  object
#  27  geoNetwork_region                                  100000 non-null  object
#  28  geoNetwork_metro                                   100000 non-null  object
#  29  geoNetwork_city                                    100000 non-null  object
#  30  geoNetwork_cityId                                  100000 non-null  object
#  31  geoNetwork_networkDomain                           100000 non-null  object
#  32  geoNetwork_latitude                                100000 non-null  object
#  33  geoNetwork_longitude                               100000 non-null  object
#  34  geoNetwork_networkLocation                         100000 non-null  object
#  35  totals_visits                                      100000 non-null  int64
#  36  totals_hits                                        100000 non-null  int64
#  37  totals_pageviews                                   100000 non-null  int64
#  38  totals_bounces                                     49854 non-null   float64
#  39  totals_newVisits                                   76365 non-null   float64
#  40  totals_sessionQualityDim                           46128 non-null   float64
#  41  totals_timeOnSite                                  50026 non-null   float64
#  42  totals_transactions                                1002 non-null    float64
#  43  totals_transactionRevenue                          100000 non-null  int64
#  44  totals_totalTransactionRevenue                     997 non-null     float64
#  45  trafficSource_campaign                             100000 non-null  object
#  46  trafficSource_source                               100000 non-null  object
#  47  trafficSource_medium                               100000 non-null  object
#  48  trafficSource_keyword                              30782 non-null   object
#  49  trafficSource_adwordsClickInfo.criteriaParameters  100000 non-null  object
#  50  trafficSource_referralPath                         34157 non-null   object
#  51  trafficSource_isTrueDirect                         30462 non-null   object
#  52  trafficSource_adContent                            3763 non-null    object
#  53  trafficSource_adwordsClickInfo.page                4391 non-null    float64
#  54  trafficSource_adwordsClickInfo.slot                4391 non-null    object
#  55  trafficSource_adwordsClickInfo.gclId               4429 non-null    object
#  56  trafficSource_adwordsClickInfo.adNetworkType       4391 non-null    object
#  57  trafficSource_adwordsClickInfo.isVideoAd           4391 non-null    object
# dtypes: float64(7), int64(10), object(40), uint64(1)
# memory usage: 44.3+ MB

# %%
df['date']
# Out:
# 0        20171016
# 1        20171016
# 2        20171016
# 3        20171016
# 4        20171016
#            ...
# 99995    20170529
# 99996    20170529
# 99997    20170529
# 99998    20170529
# 99999    20170529
# Name: date, Length: 100000, dtype: int64

# %%
df['date'].astype('str')
# Out:
# 0        20171016
# 1        20171016
# 2        20171016
# 3        20171016
# 4        20171016
#            ...
# 99995    20170529
# 99996    20170529
# 99997    20170529
# 99998    20170529
# 99999    20170529
# Name: date, Length: 100000, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'].astype('str'))

# %%
df['date'].hist(bins=25)
plt.xticks(rotation=90)
plt.show()

# %%
df['date'].max() - df['date'].min()
# Out:
# Timedelta('626 days 00:00:00')

# %%
window_X = pd.Timedelta('90D')
gap = pd.Timedelta('30D')
window_y = pd.Timedelta('60D')

# %%
mask = (df['date'].min() + window_X > df['date']) & (df['date'] > df['date'].min())
X1 = df[mask]
X1
# Out:
#        Unnamed: 0 channelGrouping       date        fullVisitorId  \
# 2989         2989  Organic Search 2016-09-02  6664099241683785419
# 2990         2990  Organic Search 2016-09-02  2673646440140935018
# 2991         2991  Organic Search 2016-09-02  8154446893490491402
# 2992         2992  Organic Search 2016-09-02  6335452812400381264
# 2993         2993  Organic Search 2016-09-02  7394449768324113084
# ...           ...             ...        ...                  ...
# 92489       92489          Direct 2016-10-14  8265030181325120526
# 92490       92490  Organic Search 2016-10-14  2691311962402313966
# 92491       92491     Paid Search 2016-10-14  8041285888074428900
# 92492       92492  Organic Search 2016-10-14   244988883787230241
# 92493       92493  Organic Search 2016-10-14  8041285888074428900
#
#        socialEngagementType     visitId  visitNumber  visitStartTime  \
# 2989   Not Socially Engaged  1472812272            1      1472812272
# 2990   Not Socially Engaged  1472856874            1      1472856874
# 2991   Not Socially Engaged  1472811524            1      1472811524
# 2992   Not Socially Engaged  1472823508            1      1472823508
# 2993   Not Socially Engaged  1472839619            1      1472839619
# ...                     ...         ...          ...             ...
# 92489  Not Socially Engaged  1476436745            2      1476436745
# 92490  Not Socially Engaged  1476479752            1      1476479752
# 92491  Not Socially Engaged  1476469643            2      1476469643
# 92492  Not Socially Engaged  1476440353            1      1476440353
# 92493  Not Socially Engaged  1476496598            1      1476496598
#
#       device_browser          device_browserVersion  ...  \
# 2989         Firefox  not available in demo dataset  ...
# 2990          Chrome  not available in demo dataset  ...
# 2991          Chrome  not available in demo dataset  ...
# 2992          Safari  not available in demo dataset  ...
# 2993          Chrome  not available in demo dataset  ...
# ...              ...                            ...  ...
# 92489         Chrome  not available in demo dataset  ...
# 92490         Chrome  not available in demo dataset  ...
# 92491         Chrome  not available in demo dataset  ...
# 92492         Chrome  not available in demo dataset  ...
# 92493         Safari  not available in demo dataset  ...
#
#       trafficSource_keyword trafficSource_adwordsClickInfo.criteriaParameters  \
# 2989         (not provided)                     not available in demo dataset
# 2990         (not provided)                     not available in demo dataset
# 2991         (not provided)                     not available in demo dataset
# 2992         (not provided)                     not available in demo dataset
# 2993         (not provided)                     not available in demo dataset
# ...                     ...                                               ...
# 92489                   NaN                     not available in demo dataset
# 92490                   NaN                     not available in demo dataset
# 92491                   NaN                     not available in demo dataset
# 92492                   NaN                     not available in demo dataset
# 92493                   NaN                     not available in demo dataset
#
#       trafficSource_referralPath  trafficSource_isTrueDirect  \
# 2989                         NaN                         NaN
# 2990                         NaN                         NaN
# 2991                         NaN                         NaN
# 2992                         NaN                         NaN
# 2993                         NaN                         NaN
# ...                          ...                         ...
# 92489                        NaN                        True
# 92490                        NaN                         NaN
# 92491                        NaN                        True
# 92492                        NaN                         NaN
# 92493                        NaN                         NaN
#
#       trafficSource_adContent trafficSource_adwordsClickInfo.page  \
# 2989                      NaN                                 NaN
# 2990                      NaN                                 NaN
# 2991                      NaN                                 NaN
# 2992                      NaN                                 NaN
# 2993                      NaN                                 NaN
# ...                       ...                                 ...
# 92489                     NaN                                 NaN
# 92490                     NaN                                 NaN
# 92491                     NaN                                 1.0
# 92492                     NaN                                 NaN
# 92493                     NaN                                 NaN
#
#       trafficSource_adwordsClickInfo.slot  \
# 2989                                  NaN
# 2990                                  NaN
# 2991                                  NaN
# 2992                                  NaN
# 2993                                  NaN
# ...                                   ...
# 92489                                 NaN
# 92490                                 NaN
# 92491                                 Top
# 92492                                 NaN
# 92493                                 NaN
#
#                     trafficSource_adwordsClickInfo.gclId  \
# 2989                                                 NaN
# 2990                                                 NaN
# 2991                                                 NaN
# 2992                                                 NaN
# 2993                                                 NaN
# ...                                                  ...
# 92489                                                NaN
# 92490                                                NaN
# 92491  CjwKEAjwhILABRDwo8mlqt6ug38SJACNSq_khwsXe7Rxd5...
# 92492                                                NaN
# 92493                                                NaN
#
#       trafficSource_adwordsClickInfo.adNetworkType  \
# 2989                                           NaN
# 2990                                           NaN
# 2991                                           NaN
# 2992                                           NaN
# 2993                                           NaN
# ...                                            ...
# 92489                                          NaN
# 92490                                          NaN
# 92491                                Google Search
# 92492                                          NaN
# 92493                                          NaN
#
#       trafficSource_adwordsClickInfo.isVideoAd
# 2989                                       NaN
# 2990                                       NaN
# 2991                                       NaN
# 2992                                       NaN
# 2993                                       NaN
# ...                                        ...
# 92489                                      NaN
# 92490                                      NaN
# 92491                                    False
# 92492                                      NaN
# 92493                                      NaN
#
# [5451 rows x 58 columns]

# %%
df['date'].min() + window_X
# Out:
# Timestamp('2016-11-09 00:00:00')

# %%
mask_y = (df['date'].min() + window_X + gap + window_y > df['date']) & (df['date'] > df['date'].min() + gap + window_X )
Y1 = df[mask_y]
Y1
# Out:
#        Unnamed: 0 channelGrouping       date        fullVisitorId  \
# 8780         8780  Organic Search 2017-01-26   238299079565960449
# 8781         8781  Organic Search 2017-01-26  2873793336796726549
# 8782         8782  Organic Search 2017-01-26  4484004977153719206
# 8783         8783  Organic Search 2017-01-26  2938550445207755791
# 8784         8784  Organic Search 2017-01-26  3861508872157158691
# ...           ...             ...        ...                  ...
# 88141       88141          Social 2017-01-11  8781365473772765295
# 88142       88142          Social 2017-01-11  5869608911890176679
# 88143       88143          Social 2017-01-11   766196273866587875
# 88144       88144          Social 2017-01-11  9421290052756424406
# 88145       88145          Social 2017-01-11  4920427231640673179
#
#        socialEngagementType     visitId  visitNumber  visitStartTime  \
# 8780   Not Socially Engaged  1485473898            1      1485473898
# 8781   Not Socially Engaged  1485463066            1      1485463066
# 8782   Not Socially Engaged  1485459628            1      1485459628
# 8783   Not Socially Engaged  1485497468            1      1485497468
# 8784   Not Socially Engaged  1485448549            1      1485448549
# ...                     ...         ...          ...             ...
# 88141  Not Socially Engaged  1484153864            2      1484153864
# 88142  Not Socially Engaged  1484189204            2      1484189204
# 88143  Not Socially Engaged  1484194294            1      1484194294
# 88144  Not Socially Engaged  1484157989            7      1484157989
# 88145  Not Socially Engaged  1484129986            1      1484129986
#
#         device_browser          device_browserVersion  ...  \
# 8780            Safari  not available in demo dataset  ...
# 8781            Chrome  not available in demo dataset  ...
# 8782            Chrome  not available in demo dataset  ...
# 8783            Chrome  not available in demo dataset  ...
# 8784            Chrome  not available in demo dataset  ...
# ...                ...                            ...  ...
# 88141           Chrome  not available in demo dataset  ...
# 88142           Chrome  not available in demo dataset  ...
# 88143           Chrome  not available in demo dataset  ...
# 88144           Chrome  not available in demo dataset  ...
# 88145  Android Webview  not available in demo dataset  ...
#
#       trafficSource_keyword trafficSource_adwordsClickInfo.criteriaParameters  \
# 8780                    NaN                     not available in demo dataset
# 8781                    NaN                     not available in demo dataset
# 8782                    NaN                     not available in demo dataset
# 8783                    NaN                     not available in demo dataset
# 8784                    NaN                     not available in demo dataset
# ...                     ...                                               ...
# 88141                   NaN                     not available in demo dataset
# 88142                   NaN                     not available in demo dataset
# 88143                   NaN                     not available in demo dataset
# 88144                   NaN                     not available in demo dataset
# 88145                   NaN                     not available in demo dataset
#
#       trafficSource_referralPath  trafficSource_isTrueDirect  \
# 8780                         NaN                         NaN
# 8781                         NaN                         NaN
# 8782                         NaN                         NaN
# 8783                         NaN                         NaN
# 8784                         NaN                         NaN
# ...                          ...                         ...
# 88141                 /yt/about/                         NaN
# 88142                     /l.php                        True
# 88143                 /yt/about/                         NaN
# 88144                          /                        True
# 88145                 /yt/about/                         NaN
#
#       trafficSource_adContent trafficSource_adwordsClickInfo.page  \
# 8780                      NaN                                 NaN
# 8781                      NaN                                 NaN
# 8782                      NaN                                 NaN
# 8783                      NaN                                 NaN
# 8784                      NaN                                 NaN
# ...                       ...                                 ...
# 88141                     NaN                                 NaN
# 88142                     NaN                                 NaN
# 88143                     NaN                                 NaN
# 88144                     NaN                                 NaN
# 88145                     NaN                                 NaN
#
#       trafficSource_adwordsClickInfo.slot  \
# 8780                                  NaN
# 8781                                  NaN
# 8782                                  NaN
# 8783                                  NaN
# 8784                                  NaN
# ...                                   ...
# 88141                                 NaN
# 88142                                 NaN
# 88143                                 NaN
# 88144                                 NaN
# 88145                                 NaN
#
#       trafficSource_adwordsClickInfo.gclId  \
# 8780                                   NaN
# 8781                                   NaN
# 8782                                   NaN
# 8783                                   NaN
# 8784                                   NaN
# ...                                    ...
# 88141                                  NaN
# 88142                                  NaN
# 88143                                  NaN
# 88144                                  NaN
# 88145                                  NaN
#
#       trafficSource_adwordsClickInfo.adNetworkType  \
# 8780                                           NaN
# 8781                                           NaN
# 8782                                           NaN
# 8783                                           NaN
# 8784                                           NaN
# ...                                            ...
# 88141                                          NaN
# 88142                                          NaN
# 88143                                          NaN
# 88144                                          NaN
# 88145                                          NaN
#
#       trafficSource_adwordsClickInfo.isVideoAd
# 8780                                       NaN
# 8781                                       NaN
# 8782                                       NaN
# 8783                                       NaN
# 8784                                       NaN
# ...                                        ...
# 88141                                      NaN
# 88142                                      NaN
# 88143                                      NaN
# 88144                                      NaN
# 88145                                      NaN
#
# [11709 rows x 58 columns]

# %%
num_colum = df.select_dtypes(include='number').columns
num_colum
# Out:
# Index(['Unnamed: 0', 'fullVisitorId', 'visitId', 'visitNumber',
#        'visitStartTime', 'device_isMobile', 'totals_visits', 'totals_hits',
#        'totals_pageviews', 'totals_bounces', 'totals_newVisits',
#        'totals_sessionQualityDim', 'totals_timeOnSite', 'totals_transactions',
#        'totals_transactionRevenue', 'totals_totalTransactionRevenue',
#        'trafficSource_adwordsClickInfo.page'],
#       dtype='object')

# %%
cat_colum = df.select_dtypes(include='object').columns
cat_colum
# Out:
# Index(['channelGrouping', 'socialEngagementType', 'device_browser',
#        'device_browserVersion', 'device_browserSize', 'device_operatingSystem',
#        'device_operatingSystemVersion', 'device_mobileDeviceBranding',
#        'device_mobileDeviceModel', 'device_mobileInputSelector',
#        'device_mobileDeviceInfo', 'device_mobileDeviceMarketingName',
#        'device_flashVersion', 'device_language', 'device_screenColors',
#        'device_screenResolution', 'device_deviceCategory',
#        'geoNetwork_continent', 'geoNetwork_subContinent', 'geoNetwork_country',
#        'geoNetwork_region', 'geoNetwork_metro', 'geoNetwork_city',
#        'geoNetwork_cityId', 'geoNetwork_networkDomain', 'geoNetwork_latitude',
#        'geoNetwork_longitude', 'geoNetwork_networkLocation',
#        'trafficSource_campaign', 'trafficSource_source',
#        'trafficSource_medium', 'trafficSource_keyword',
#        'trafficSource_adwordsClickInfo.criteriaParameters',
#        'trafficSource_referralPath', 'trafficSource_isTrueDirect',
#        'trafficSource_adContent', 'trafficSource_adwordsClickInfo.slot',
#        'trafficSource_adwordsClickInfo.gclId',
#        'trafficSource_adwordsClickInfo.adNetworkType',
#        'trafficSource_adwordsClickInfo.isVideoAd'],
#       dtype='object')

# %%
def get_mode(column):
  mode = column.mode()
  if len(mode) != 0:
    return mode[0]
  else:
    return 'None'

# %%
params = {}

for item in num_colum:
  params[item] = ['mean', 'sum', 'min', 'max']

params

for item in cat_colum:
  params[item] = [get_mode]

params
# Out:
# {'Unnamed: 0': ['mean', 'sum', 'min', 'max'],
#  'fullVisitorId': ['mean', 'sum', 'min', 'max'],
#  'visitId': ['mean', 'sum', 'min', 'max'],
#  'visitNumber': ['mean', 'sum', 'min', 'max'],
#  'visitStartTime': ['mean', 'sum', 'min', 'max'],
#  'device_isMobile': ['mean', 'sum', 'min', 'max'],
#  'totals_visits': ['mean', 'sum', 'min', 'max'],
#  'totals_hits': ['mean', 'sum', 'min', 'max'],
#  'totals_pageviews': ['mean', 'sum', 'min', 'max'],
#  'totals_bounces': ['mean', 'sum', 'min', 'max'],
#  'totals_newVisits': ['mean', 'sum', 'min', 'max'],
#  'totals_sessionQualityDim': ['mean', 'sum', 'min', 'max'],
#  'totals_timeOnSite': ['mean', 'sum', 'min', 'max'],
#  'totals_transactions': ['mean', 'sum', 'min', 'max'],
#  'totals_transactionRevenue': ['mean', 'sum', 'min', 'max'],
#  'totals_totalTransactionRevenue': ['mean', 'sum', 'min', 'max'],
#  'trafficSource_adwordsClickInfo.page': ['mean', 'sum', 'min', 'max'],
#  'channelGrouping': [<function __main__.get_mode(column)>],
#  'socialEngagementType': [<function __main__.get_mode(column)>],
#  'device_browser': [<function __main__.get_mode(column)>],
#  'device_browserVersion': [<function __main__.get_mode(column)>],
#  'device_browserSize': [<function __main__.get_mode(column)>],
#  'device_operatingSystem': [<function __main__.get_mode(column)>],
#  'device_operatingSystemVersion': [<function __main__.get_mode(column)>],
#  'device_mobileDeviceBranding': [<function __main__.get_mode(column)>],
#  'device_mobileDeviceModel': [<function __main__.get_mode(column)>],
#  'device_mobileInputSelector': [<function __main__.get_mode(column)>],
#  'device_mobileDeviceInfo': [<function __main__.get_mode(column)>],
#  'device_mobileDeviceMarketingName': [<function __main__.get_mode(column)>],
#  'device_flashVersion': [<function __main__.get_mode(column)>],
#  'device_language': [<function __main__.get_mode(column)>],
#  'device_screenColors': [<function __main__.get_mode(column)>],
#  'device_screenResolution': [<function __main__.get_mode(column)>],
#  'device_deviceCategory': [<function __main__.get_mode(column)>],
#  'geoNetwork_continent': [<function __main__.get_mode(column)>],
#  'geoNetwork_subContinent': [<function __main__.get_mode(column)>],
#  'geoNetwork_country': [<function __main__.get_mode(column)>],
#  'geoNetwork_region': [<function __main__.get_mode(column)>],
#  'geoNetwork_metro': [<function __main__.get_mode(column)>],
#  'geoNetwork_city': [<function __main__.get_mode(column)>],
#  'geoNetwork_cityId': [<function __main__.get_mode(column)>],
#  'geoNetwork_networkDomain': [<function __main__.get_mode(column)>],
#  'geoNetwork_latitude': [<function __main__.get_mode(column)>],
#  'geoNetwork_longitude': [<function __main__.get_mode(column)>],
#  'geoNetwork_networkLocation': [<function __main__.get_mode(column)>],
#  'trafficSource_campaign': [<function __main__.get_mode(column)>],
#  'trafficSource_source': [<function __main__.get_mode(column)>],
#  'trafficSource_medium': [<function __main__.get_mode(column)>],
#  'trafficSource_keyword': [<function __main__.get_mode(column)>],
#  'trafficSource_adwordsClickInfo.criteriaParameters': [<function __main__.get_mode(column)>],
#  'trafficSource_referralPath': [<function __main__.get_mode(column)>],
#  'trafficSource_isTrueDirect': [<function __main__.get_mode(column)>],
#  'trafficSource_adContent': [<function __main__.get_mode(column)>],
#  'trafficSource_adwordsClickInfo.slot': [<function __main__.get_mode(column)>],
#  'trafficSource_adwordsClickInfo.gclId': [<function __main__.get_mode(column)>],
#  'trafficSource_adwordsClickInfo.adNetworkType': [<function __main__.get_mode(column)>],
#  'trafficSource_adwordsClickInfo.isVideoAd': [<function __main__.get_mode(column)>]}

# %%
X1.groupby(by = 'fullVisitorId').agg(params)
# Out:
#                        Unnamed: 0                      fullVisitorId  \
#                              mean     sum   min    max          mean
# fullVisitorId
# 4681782413258180     69164.250000  276657  5426  91379  4.681782e+15
# 4716754086642834     39720.700000  397207  3015  92350  4.716754e+15
# 21234147381275782    25245.750000  100983  3213  89679  2.123415e+16
# 24221961786219821    41712.000000  291984  3992  92103  2.422196e+16
# 34208980776585217    18980.000000  113880  3118  92364  3.420898e+16
# ...                           ...     ...   ...    ...           ...
# 9947026042460614024  73664.000000  368320  3462  91750  9.947026e+18
# 9958282727161780218  38341.200000  191706  3078  90944  9.958283e+18
# 9959375007479901087  48648.000000   97296  5508  91788  9.959375e+18
# 9972297848679017937  74018.200000  370091  3295  92239  9.972298e+18
# 9977822218056364912  47487.833333  284927  3193  91904  9.977822e+18
#
#                                                                 \
#                                       sum                  min
# fullVisitorId
# 4681782413258180        18727129653032720     4681782413258180
# 4716754086642834        47167540866428340     4716754086642834
# 21234147381275782       84936589525103128    21234147381275782
# 24221961786219821      169553732503538747    24221961786219821
# 34208980776585217      205253884659511302    34208980776585217
# ...                                   ...                  ...
# 9947026042460614024  12841642064883966888  9947026042460614024
# 9958282727161780218  12897925488389797858  9958282727161780218
# 9959375007479901087   1472005941250250558  9959375007479901087
# 9972297848679017937  12968001095975986453  9972297848679017937
# 9977822218056364912   4526701087209534624  9977822218056364912
#
#                                                visitId               ...  \
#                                      max          mean          sum  ...
# fullVisitorId                                                        ...
# 4681782413258180        4681782413258180  1.475565e+09   5902258812  ...
# 4716754086642834        4716754086642834  1.474289e+09  14742894354  ...
# 21234147381275782      21234147381275782  1.473752e+09   5895007011  ...
# 24221961786219821      24221961786219821  1.474409e+09  10320863710  ...
# 34208980776585217      34208980776585217  1.473435e+09   8840609142  ...
# ...                                  ...           ...          ...  ...
# 9947026042460614024  9947026042460614024  1.475735e+09   7378673191  ...
# 9958282727161780218  9958282727161780218  1.474278e+09   7371391405  ...
# 9959375007479901087  9959375007479901087  1.474652e+09   2949303542  ...
# 9972297848679017937  9972297848679017937  1.475754e+09   7378771045  ...
# 9977822218056364912  9977822218056364912  1.474657e+09   8847939227  ...
#
#                     trafficSource_medium trafficSource_keyword  \
#                                 get_mode              get_mode
# fullVisitorId
# 4681782413258180                  (none)                  None
# 4716754086642834                  (none)        (not provided)
# 21234147381275782                 (none)        (not provided)
# 24221961786219821                 (none)        (not provided)
# 34208980776585217               referral        (not provided)
# ...                                  ...                   ...
# 9947026042460614024             referral                  None
# 9958282727161780218               (none)        (not provided)
# 9959375007479901087             referral                  None
# 9972297848679017937            affiliate                  None
# 9977822218056364912               (none)                  None
#
#                     trafficSource_adwordsClickInfo.criteriaParameters  \
#                                                              get_mode
# fullVisitorId
# 4681782413258180                        not available in demo dataset
# 4716754086642834                        not available in demo dataset
# 21234147381275782                       not available in demo dataset
# 24221961786219821                       not available in demo dataset
# 34208980776585217                       not available in demo dataset
# ...                                                               ...
# 9947026042460614024                     not available in demo dataset
# 9958282727161780218                     not available in demo dataset
# 9959375007479901087                     not available in demo dataset
# 9972297848679017937                     not available in demo dataset
# 9977822218056364912                     not available in demo dataset
#
#                     trafficSource_referralPath trafficSource_isTrueDirect  \
#                                       get_mode                   get_mode
# fullVisitorId
# 4681782413258180                    /yt/about/                       True
# 4716754086642834                    /yt/about/                       True
# 21234147381275782                            /                       None
# 24221961786219821                            /                       True
# 34208980776585217              /optimize/home/                       True
# ...                                        ...                        ...
# 9947026042460614024              /yt/about/fr/                       True
# 9958282727161780218           /yt/about/en-GB/                       True
# 9959375007479901087                 /yt/about/                       True
# 9972297848679017937              /yt/about/ar/                       True
# 9977822218056364912                          /                       True
#
#                     trafficSource_adContent  \
#                                    get_mode
# fullVisitorId
# 4681782413258180                       None
# 4716754086642834                       None
# 21234147381275782                      None
# 24221961786219821                      None
# 34208980776585217                      None
# ...                                     ...
# 9947026042460614024                    None
# 9958282727161780218                    None
# 9959375007479901087                    None
# 9972297848679017937                    None
# 9977822218056364912                    None
#
#                     trafficSource_adwordsClickInfo.slot  \
#                                                get_mode
# fullVisitorId
# 4681782413258180                                   None
# 4716754086642834                                    Top
# 21234147381275782                                  None
# 24221961786219821                                  None
# 34208980776585217                                  None
# ...                                                 ...
# 9947026042460614024                                None
# 9958282727161780218                                None
# 9959375007479901087                                None
# 9972297848679017937                                None
# 9977822218056364912                                None
#
#                                   trafficSource_adwordsClickInfo.gclId  \
#                                                               get_mode
# fullVisitorId
# 4681782413258180                                                  None
# 4716754086642834     Cj0KEQjwxqS-BRDRgPLp0q2t0IUBEiQAgfMXRMY-4jVpxN...
# 21234147381275782                                                 None
# 24221961786219821                                                 None
# 34208980776585217                                                 None
# ...                                                                ...
# 9947026042460614024                                               None
# 9958282727161780218                                               None
# 9959375007479901087                                               None
# 9972297848679017937                                               None
# 9977822218056364912                                               None
#
#                     trafficSource_adwordsClickInfo.adNetworkType  \
#                                                         get_mode
# fullVisitorId
# 4681782413258180                                            None
# 4716754086642834                                   Google Search
# 21234147381275782                                           None
# 24221961786219821                                           None
# 34208980776585217                                           None
# ...                                                          ...
# 9947026042460614024                                         None
# 9958282727161780218                                         None
# 9959375007479901087                                         None
# 9972297848679017937                                         None
# 9977822218056364912                                         None
#
#                     trafficSource_adwordsClickInfo.isVideoAd
#                                                     get_mode
# fullVisitorId
# 4681782413258180                                        None
# 4716754086642834                                       False
# 21234147381275782                                       None
# 24221961786219821                                       None
# 34208980776585217                                       None
# ...                                                      ...
# 9947026042460614024                                     None
# 9958282727161780218                                     None
# 9959375007479901087                                     None
# 9972297848679017937                                     None
# 9977822218056364912                                     None
#
# [991 rows x 108 columns]
